# %% [markdown]
# https://huggingface.co/ChenMnZ

# %%
# !pip install optimum
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 45.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install auto-gptq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 51.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 33.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 66.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.0 MB/s eta 0:00:00
# ...

# %%
# !pip install gptqmodel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 64.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 102.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 29.8 MB/s eta 0:00:00
# ...
#   Created wheel for gptqmodel: filename=gptqmodel-1.9.0-cp311-cp311-linux_x86_64.whl size=12183061 sha256=dce66d5031ab98a45aef5fab78ed440813e427454d282eb0b698546997f09b8a
#   Stored in directory: /root/.cache/pip/wheels/75/dc/a8/85f4e3aafe265c6f4df9f372b22be86b20de8d1b65b0680268
# ...
#   Created wheel for device-smi: filename=device_smi-0.3.3-py3-none-any.whl size=15578 sha256=0abe960e6944d07060deb867cad0a07773101eafc3140901331e61447edb007e
# ...

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel

quant_dir = "ChenMnZ/Llama-2-7b-EfficientQAT-w2g128-GPTQ"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)
model = GPTQModel.from_quantized(quant_dir)

generation_config = GenerationConfig(max_new_tokens=5)  # Set to your desired value

print(tokenizer.decode(model.generate(
    **tokenizer("Model quantization is", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# ...

# %%
generation_config = GenerationConfig(max_new_tokens=55)  # Set to your desired value

print(tokenizer.decode(model.generate(
    **tokenizer("Who is Sherlock Holmes?", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))
# Out:
# <s> Who is Sherlock Holmes?
# The first Sherlock Holmes was created by the author Sir Arthur Conan Doyle in 1887. He was a fictional detective who solved crimes in London.
# Who is Sherlock Holmes?
# Sherlock Holmes is a

# %%
generation_config = GenerationConfig(max_new_tokens=55)  # Set to your desired value

print(tokenizer.decode(model.generate(
    **tokenizer("Who is Arthur Conan Doyle?", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))
# Out:
# <s> Who is Arthur Conan Doyle?
# Who is Arthur Conan Doyle?
# Arthur Conan Doyle was born in Edinburgh, Scotland, on July 18, 1859. He was the son of a wealthy family. His father was a successful businessman and his mother

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel

quant_dir = "ChenMnZ/Llama-2-7b-EfficientQAT-w2g128-GPTQ"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)
model = GPTQModel.from_quantized(quant_dir)

generation_config = GenerationConfig(max_new_tokens=5)  # Set to your desired value

print(tokenizer.decode(model.generate(
    **tokenizer("Model quantization is", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))

# %%
ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-BitBLAS

ChenMnZ/Llama-3-70b-EfficientQAT-w2g64-BitBLAS

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel

quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-BitBLAS"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)
model = GPTQModel.from_quantized(quant_dir)

generation_config = GenerationConfig(max_new_tokens=5)  # Set to your desired value

print(tokenizer.decode(model.generate(
    **tokenizer("Model quantization is", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# ...

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch

quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-BitBLAS"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)
model = GPTQModel.from_quantized(quant_dir, device_map="auto")

generation_config = GenerationConfig(max_new_tokens=5)  # Set to your desired value

print(tokenizer.decode(model.generate(
    **tokenizer("Model quantization is", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))
# Out:
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# INFO - Estimated Quantization BPW (bits per weight): 2.34375 bpw, based on [bits: 2, group_size: 64]
# INFO - Auto enabling flash attention2
# INFO - make_quant: Linear candidates: [<class 'gptqmodel.nn_modules.qlinear.bitblas.BitBLASQuantLinear'>]
# WARNING - TVM target not found. Please set the TVM target environment variable using `export TVM_TARGET=<target>`, where <target> is one of the available targets can be found in the output of `tools/get_available_targets.py`.
# BITBLAS_TARGET cuda
# BITBLAS_DATABASE_PATH: /root/.cache/bitblas_0.1.0.post1
# 2025-02-24 02:00:08 [BitBLAS:INFO]: Database path /root/.cache/bitblas_0.1.0.post1 does not exist, skipping loading operators from the database
# ...

# %%
model = GPTQModel.from_quantized(quant_dir, load_in_8bit=True, device_map="auto")

# %%
# !pip install bitblas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 MB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 70.1 MB/s eta 0:00:00
# ...

# %%
kaitchup/Qwen2.5-72B-Instruct-AutoRound-GPTQ-2bit

kaitchup/Meta-Llama-3.1-70B-Instruct-ExLlamaV2-2.2bit
kaitchup/Meta-Llama-3.1-70B-Instruct-ExLlamaV2-2.2bit
https://github.com/turboderp-org/exllamav2
https://github.com/turboderp-org/exllamav2/blob/master/examples/chat_example.ipynb

# %% [markdown]
# https://huggingface.co/kaitchup/Meta-Llama-3.1-70B-Instruct-ExLlamaV2-2.2bit

# %%
import transformers
import torch

model_id = "kaitchup/Meta-Llama-3.1-70B-Instruct-ExLlamaV2-2.2bit"

pipeline = transformers.pipeline(
    "text-generation",
    model=model_id,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device_map="auto",
)

messages = [
    {"role": "system", "content": "You are a pirate chatbot who always responds in pirate speak!"},
    {"role": "user", "content": "Who are you?"},
]

outputs = pipeline(
    messages,
    max_new_tokens=256,
)
print(outputs[0]["generated_text"][-1])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-04f446061244> in <cell line: 0>()
#       4 model_id = "kaitchup/Meta-Llama-3.1-70B-Instruct-ExLlamaV2-2.2bit"
#       5
# ----> 6 pipeline = transformers.pipeline(
#       7     "text-generation",
#       8     model=model_id,
#
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "meta-llama/Meta-Llama-3.1-70B-Instruct"
quantization_config = BitsAndBytesConfig(load_in_8bit=True)

quantized_model = AutoModelForCausalLM.from_pretrained(
    model_id, device_map="auto", torch_dtype=torch.bfloat16, quantization_config=quantization_config)

tokenizer = AutoTokenizer.from_pretrained(model_id)
input_text = "What are we having for dinner?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

output = quantized_model.generate(**input_ids, max_new_tokens=10)

print(tokenizer.decode(output[0], skip_special_tokens=True))

# %%
from transformers import AutoTokenizer
from gptqmodel import GPTQModel

quant_dir = "ChenMnZ/Llama-2-7b-EfficientQAT-w2g128-GPTQ"
# quant_dir = "ChenMnZ/Llama-2-7b-EfficientQAT-w2g128-BitBLAS"
# or local path

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)


# load quantized model to the first GPU
model = GPTQModel.from_quantized(quant_dir)

# inference with model.generate
print(tokenizer.decode(model.generate(**tokenizer("Model quantization is", return_tensors="pt").to(model.device))[0]))

# %%
device_map="auto", torch_dtype=torch.bfloat16

# %%
from transformers import AutoTokenizer
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"


tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)


# load quantized model to the first GPU
model = GPTQModel.from_quantized(quant_dir, torch_dtype=torch.bfloat16, device_map="auto")

generation_config = GenerationConfig(max_new_tokens=5)  # Set to your desired value

print(tokenizer.decode(model.generate(
    **tokenizer("Model quantization is", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# ...

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel

quant_dir = "ChenMnZ/Llama-2-7b-EfficientQAT-w2g128-GPTQ"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)
model = GPTQModel.from_quantized(quant_dir)

generation_config = GenerationConfig(max_new_tokens=5)  # Set to your desired value

print(tokenizer.decode(model.generate(
    **tokenizer("Model quantization is", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)

# load quantized model to the first GPU
model = GPTQModel.from_quantized(quant_dir, torch_dtype=torch.bfloat16, device_map="auto")

# تعطيل Flash Attention 2
model.config.use_flash_attention_2 = False

generation_config = GenerationConfig(max_new_tokens=5)

print(tokenizer.decode(model.generate(
    **tokenizer("Model quantization is", return_tensors="pt").to(model.device),
    generation_config=generation_config
)[0]))
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# ...

# %%
generation_config = GenerationConfig(max_new_tokens=5, batch_size=1)

# %%
model = GPTQModel.from_quantized(quant_dir, torch_dtype=torch.bfloat16, device_map="auto", load_in_8bit=True)

# %%
del some_variable
import gc
gc.collect()

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
import gc
del some_variable
import gc
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3c49fb2df57f> in <cell line: 0>()
#       1 import gc
# ----> 2 del some_variable
#       3 import gc
#       4 gc.collect()
#
# NameError: name 'some_variable' is not defined

# %%
# Instead of trying to delete a variable that may not exist,
# check if it exists before attempting to delete it.
# This avoids the NameError.
import gc

if 'some_variable' in locals() or 'some_variable' in globals():
    del some_variable

gc.collect()
# Out:
# 0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d284b3ce4d36> in <cell line: 0>()
# ----> 1 model.config.use_flash_attention_2 = False
#
# NameError: name 'model' is not defined

# %%
model = GPTQModel.from_quantized(quant_dir, torch_dtype=torch.bfloat16, device_map="auto")
model.config.use_flash_attention_2 = False
# Out:
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# INFO - Estimated Quantization BPW (bits per weight): 2.34375 bpw, based on [bits: 2, group_size: 64]
# INFO - Auto enabling flash attention2
# INFO - Auto pick kernel based on compatibility: <class 'gptqmodel.nn_modules.qlinear.tritonv2.TritonV2QuantLinear'>
# INFO - make_quant: Linear candidates: [<class 'gptqmodel.nn_modules.qlinear.tritonv2.TritonV2QuantLinear'>, <class 'gptqmodel.nn_modules.qlinear.dynamic_cuda.DynamicCudaQuantLinear'>, <class 'gptqmodel.nn_modules.qlinear.torch.TorchQuantLinear'>]

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)
model = GPTQModel.from_quantized(quant_dir, torch_dtype="auto", device_map="auto")
model.config.use_flash_attention_2 = False
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# ...

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

tokenizer = AutoTokenizer.from_pretrained(quant_dir, use_fast=True)
model = GPTQModel.from_quantized(quant_dir, torch_dtype="auto", device_map="auto")
model.config.use_flash_attention_2 = False

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.

# %%
print(model.hf_device_map)
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Model device: {next(model.parameters()).device}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e0515b06d950> in <cell line: 0>()
# ----> 1 print(model.hf_device_map)
#       2 print(f"CUDA available: {torch.cuda.is_available()}")
#       3 print(f"Model device: {next(model.parameters()).device}")
#
# NameError: name 'model' is not defined

# %%
model = GPTQModel.from_quantized(quant_dir, torch_dtype=torch.float16, device_map={"": 0})
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# INFO - Estimated Quantization BPW (bits per weight): 2.34375 bpw, based on [bits: 2, group_size: 64]
# INFO - Auto enabling flash attention2
# ...

# %%
print(model.hf_device_map)
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Model device: {next(model.parameters()).device}")

# %%
model.to("cuda")

# %%
model = GPTQModel.from_quantized(
    quant_dir,
    torch_dtype=torch.float16,
    device_map="sequential",
    max_memory={0: "13GiB"}  # تخصيص 13 جيجا بايت فقط لـ GPU
)

# %%
model.config.use_flash_attention_2 = False
model.config.pretraining_tp = 1

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.

# %%
model = GPTQModel.from_quantized(
    quant_dir,
    torch_dtype=torch.float16,

    device_map="auto",
    max_memory={0: "13GiB"}  # تخصيص 13 جيجا بايت فقط لـ GPU
)
# Out:
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# INFO - Estimated Quantization BPW (bits per weight): 2.34375 bpw, based on [bits: 2, group_size: 64]
# INFO - Auto enabling flash attention2
# INFO - Auto pick kernel based on compatibility: <class 'gptqmodel.nn_modules.qlinear.tritonv2.TritonV2QuantLinear'>
# INFO - make_quant: Linear candidates: [<class 'gptqmodel.nn_modules.qlinear.tritonv2.TritonV2QuantLinear'>, <class 'gptqmodel.nn_modules.qlinear.dynamic_cuda.DynamicCudaQuantLinear'>, <class 'gptqmodel.nn_modules.qlinear.torch.TorchQuantLinear'>]

# %%
from auto_gptq import AutoGPTQForCausalLM

model = AutoGPTQForCausalLM.from_quantized(
    quant_dir,
    torch_dtype=torch.float16,
    device_map="auto"
)
# Out:
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:418: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:461: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float16)
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# ...

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.

# %%
model = GPTQModel.from_quantized(
    quant_dir,
    torch_dtype="auto",
    device_map="sequential",
    max_memory={0: "13GiB", "cpu": "30GiB"}
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-689e06629c34> in <cell line: 0>()
# ----> 1 model = GPTQModel.from_quantized(
#       2     quant_dir,
#       3     torch_dtype="auto",
#       4     device_map="sequential",
#       5     max_memory={0: "13GiB", "cpu": "30GiB"}
#
# ...

# %%
model = GPTQModel.from_quantized(
    quant_dir,
    torch_dtype="auto",
    device_map="auto",  # Change device_map to "auto"
    max_memory={0: "13GiB", "cpu": "30GiB"}
)
# Out:
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# INFO - Estimated Quantization BPW (bits per weight): 2.34375 bpw, based on [bits: 2, group_size: 64]
# INFO - Auto enabling flash attention2
# INFO - Auto pick kernel based on compatibility: <class 'gptqmodel.nn_modules.qlinear.tritonv2.TritonV2QuantLinear'>
# INFO - make_quant: Linear candidates: [<class 'gptqmodel.nn_modules.qlinear.tritonv2.TritonV2QuantLinear'>, <class 'gptqmodel.nn_modules.qlinear.dynamic_cuda.DynamicCudaQuantLinear'>, <class 'gptqmodel.nn_modules.qlinear.torch.TorchQuantLinear'>]

# %%
from transformers import AutoTokenizer, GenerationConfig
from gptqmodel import GPTQModel
import torch
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.

# %%
model = GPTQModel.from_quantized(
    quant_dir,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# INFO - Estimated Quantization BPW (bits per weight): 2.34375 bpw, based on [bits: 2, group_size: 64]
# INFO - Auto enabling flash attention2
# ...

# %%
from transformers import pipeline

messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe = pipeline("text-generation", model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ")
pipe(messages)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
    torch_dtype="auto",
    device_map="auto",

# %%
from transformers import pipeline
import torch
messages = [
    {"role": "user", "content": "Who are you?"},
]

pipe = pipeline(
    "text-generation",
    model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ",
    torch_dtype="auto",
    device_map="auto",
    max_new_tokens=5  # Add this line to control the length of generated text
)

result = pipe(messages)
print(result[0]['generated_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
    torch_dtype="auto",
    device_map="auto",

# %%
from transformers import pipeline
import torch
# Load the model pipeline
pipe = pipeline("text-generation", model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ", trust_remote_code=True, torch_dtype="auto", device_map="auto")

# Use a properly formatted string as input, with do_sample
response = pipe("Who are you?", max_new_tokens=5, do_sample=True)

# Print response
print(response[0]['generated_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
low_cpu_mem_usage

# %%
from transformers import pipeline
import torch

# Load the model pipeline
pipe = pipeline("text-generation", model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ", trust_remote_code=True, torch_dtype="auto", device_map="auto")

# Use a properly formatted string as input, with do_sample
response = pipe("Who are you?", max_new_tokens=5, do_sample=True, batch_size=1)  # Setting batch_size

# Print response
print(response[0]['generated_text'])

# %%
import os
import torch
from transformers import pipeline

# Set environment variable for memory allocation
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# Enable low CPU memory usage
# This is relevant for text generation, where the tokenizer and model might be loaded multiple times
os.environ['TRANSFORMERS_OFFLINE'] = '1'
# If you are also using bitsandbytes, enable this:
os.environ['BITSANDBYTES_NOWELCOME'] = '1'

# Load the model pipeline
pipe = pipeline(
    "text-generation",
    model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ",
    trust_remote_code=True,
    torch_dtype="auto",
    device_map="auto",
    low_cpu_mem_usage=True  # Enable low CPU memory usage
)

messages = [
    {"role": "user", "content": "Who are you?"},
]

# Generate text with limited tokens and batch size
response = pipe(messages, max_new_tokens=5, do_sample=True, batch_size=1)

# Print response
print(response[0]['generated_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
import os
import torch
from transformers import pipeline
import gc
gc.collect()
torch.cuda.empty_cache()

# Set environment variable for memory allocation
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['TRANSFORMERS_OFFLINE'] = '1'
os.environ['BITSANDBYTES_NOWELCOME'] = '1'

# Force CPU offloading for the model
device_map = {"": "cpu"}
gc.collect()
torch.cuda.empty_cache()
# Load the model pipeline with forced CPU offloading
pipe = pipeline(
    "text-generation",
    model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ",
    trust_remote_code=True,
    torch_dtype="auto",
    device_map=device_map,  # Use the device_map we defined
    low_cpu_mem_usage=True
)
gc.collect()
torch.cuda.empty_cache()
messages = [
    {"role": "user", "content": "Who are you?"},
]

# Generate text with limited tokens and batch size
response = pipe(messages, max_new_tokens=5, do_sample=True, batch_size=1)

# Print response
print(response[0]['generated_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
from transformers import pipeline
import torch
import os
import torch

import gc
gc.collect()
torch.cuda.empty_cache()


os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['TRANSFORMERS_OFFLINE'] = '1'
os.environ['BITSANDBYTES_NOWELCOME'] = '1'
gc.collect()
torch.cuda.empty_cache()

# Load the model pipeline
pipe = pipeline("text-generation", model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ", trust_remote_code=True, torch_dtype="auto", device_map="auto")

# Use a properly formatted string as input, with do_sample
response = pipe("Who are you?", max_new_tokens=5, do_sample=True, batch_size=1)  # Setting batch_size

# Print response
print(response[0]['generated_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/accelerate/utils/modeling.py:1536: UserWarning: Current model requires 9772073088 bytes of buffer for offloaded layers, which seems does not fit any GPU's remaining memory. If you are experiencing a OOM later, please consider using offload_buffers=True.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-2-b9cc51e93fa5> in <cell line: 0>()
#      16
#      17 # Load the model pipeline
# ---> 18 pipe = pipeline("text-generation", model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ", trust_remote_code=True, torch_dtype="auto", device_map="auto")
#      19
#      20 # Use a properly formatted string as input, with do_sample
#
# ...

# %%
(messages, max_new_tokens=5, do_sample=True, batch_size=1)

# %%
from transformers import AutoTokenizer, pipeline
from gptqmodel import GPTQModel
import torch
import gc
import os
gc.collect()
torch.cuda.empty_cache()


os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['TRANSFORMERS_OFFLINE'] = '1'
os.environ['BITSANDBYTES_NOWELCOME'] = '1'
gc.collect()
torch.cuda.empty_cache()

# Load the model with memory limits
model = GPTQModel.from_quantized(
    "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ",
    #device_map="auto",
    max_memory={0: "10GiB", "cpu": "10GiB"}, # Set memory limits for GPU and CPU
    trust_remote_code=True
)

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ")

# Create the pipeline with the loaded model and tokenizer
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype="auto",
)

# Use a properly formatted string as input, with do_sample
response = pipe("Who are you?", max_new_tokens=5, do_sample=True, batch_size=1)  # Setting batch_size

# Print response
print(response[0]['generated_text'])
# Out:
# ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for compatibililty.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# INFO - Ignoring unknown parameter in the quantization configuration: model_name_or_path.
# INFO - Ignoring unknown parameter in the quantization configuration: model_file_base_name.
# ...

# %%
from transformers import AutoTokenizer, pipeline
from auto_gptq import AutoGPTQForCausalLM
import torch
import gc
import os

# تنظيف الذاكرة
gc.collect()
torch.cuda.empty_cache()

# تحميل النموذج باستخدام AutoGPTQ
quant_dir = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

model = AutoGPTQForCausalLM.from_quantized(
    quant_dir,
    torch_dtype=torch.float16,  # تأكد من دعم T4 لهذا النوع
    device_map="auto",
    trust_remote_code=True
)

# تحميل التوكنيزر
tokenizer = AutoTokenizer.from_pretrained(quant_dir)

# إنشاء pipeline
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,  # تفعيل Float16 لسرعة أعلى
)

# تجربة النموذج
response = pipe("Who are you?", max_new_tokens=5, do_sample=True, batch_size=1)

print(response[0]['generated_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:418: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:461: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float16)
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# ...

# %%
import os
import torch
from transformers import pipeline
import gc

gc.collect()
torch.cuda.empty_cache()

os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['TRANSFORMERS_OFFLINE'] = '1'
os.environ['BITSANDBYTES_NOWELCOME'] = '1'
gc.collect()
torch.cuda.empty_cache()

# Define the offload folder
offload_folder = "/content/a"  # Replace with your desired path
os.makedirs(offload_folder, exist_ok=True)  # Create the folder if it doesn't exist

# Load the model pipeline with disk offloading
pipe = pipeline(
    "text-generation",
    model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ",
    trust_remote_code=True,
    torch_dtype="auto",
    device_map="auto",  # Use automatic device mapping
    offload_folder=offload_folder,
    offload_folder=True,# Enable disk offloading to the specified folder
    low_cpu_mem_usage=True
)

messages = [
    {"role": "user", "content": "Who are you?"},
]

# Generate text with limited tokens and batch size
response = pipe(messages, max_new_tokens=5, do_sample=True, batch_size=1)

# Print response
print(response[0]['generated_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
import os
import torch
from transformers import pipeline
import gc

gc.collect()
torch.cuda.empty_cache()

os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['TRANSFORMERS_OFFLINE'] = '1'
os.environ['BITSANDBYTES_NOWELCOME'] = '1'
gc.collect()
torch.cuda.empty_cache()

# Define the offload folder
offload_folder = "/content/a"  # Replace with your desired path
os.makedirs(offload_folder, exist_ok=True)  # Create the folder if it doesn't exist

# Load the model pipeline with disk offloading and max_memory
pipe = pipeline(
    "text-generation",
    model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ",
    trust_remote_code=True,
    torch_dtype="auto",
    device_map="auto",  # Use automatic device mapping
    offload_folder=offload_folder,  # Enable disk offloading to the specified folder
    low_cpu_mem_usage=True,
    model_kwargs={"max_memory": {0: "10GiB", "cpu": "10GiB"}},  # Added max_memory
)

messages = [
    {"role": "user", "content": "Who are you?"},
]

# Generate text with limited tokens and batch size
response = pipe(messages, max_new_tokens=5, do_sample=True, batch_size=1)

# Print response
print(response[0]['generated_text'])

# %% [markdown]
#     "text-generation",
#     model="ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ",
#     trust_remote_code=True,
#     torch_dtype="auto",
#     device_map="auto",  # Use automatic device mapping
#     offload_folder=offload_folder,
#     offload_folder=True,# Enable disk offloading to the specified folder
#     low_cpu_mem_usage=True
# )
#
#
# (task: str = None, model: str | PreTrainedModel | TFPreTrainedModel | None = None, config: str | PretrainedConfig | None = None, tokenizer: str | PreTrainedTokenizer | PreTrainedTokenizerFast | None = None, feature_extractor: str | Any | None = None, image_processor: str | BaseImageProcessor | None = None, processor: str | ProcessorMixin | None = None, framework: str | None = None, revision: str | None = None, use_fast: bool = True, token: str | bool | None = None, device: int | str | device | None = None, device_map: Any | None = None, torch_dtype: Any | None = None, trust_remote_code: bool | None = None, model_kwargs: Dict[str, Any] = None, pipeline_class: Any | None = None, **kwargs: Any) -> Pipeline
# kwargs (`Dict[str, Any]`, *optional*):
#
# Utility factory method to build a [Pipeline].
#
# A pipeline consists of:
#
#
# One or more components for pre-processing model inputs, such as a tokenizer,
# image_processor, feature_extractor, or processor.
#
# A model that generates predictions from the inputs.
#
# Optional post-processing steps to refine the model's output, which can also be handled by processors.
#
#
# <Tip>
# While there are such optional arguments as tokenizer, feature_extractor, image_processor, and processor,
# they shouldn't be specified all at once. If these components are not provided, pipeline will try to load
# required ones automatically. In case you want to provide these components explicitly, please refer to a
# specific pipeline in order to get more details regarding what components are required.
# </Tip>
#
# Args:
#     task (str):
#         The task defining which pipeline will be returned. Currently accepted tasks are:
#
# - `"audio-classification"`: will return a \[`AudioClassificationPipeline`\].
# - `"automatic-speech-recognition"`: will return a \[`AutomaticSpeechRecognitionPipeline`\].
# - `"depth-estimation"`: will return a \[`DepthEstimationPipeline`\].
# - `"document-question-answering"`: will return a \[`DocumentQuestionAnsweringPipeline`\].
# - `"feature-extraction"`: will return a \[`FeatureExtractionPipeline`\].
# - `"fill-mask"`: will return a \[`FillMaskPipeline`\]:.
# - `"image-classification"`: will return a \[`ImageClassificationPipeline`\].
# - `"image-feature-extraction"`: will return an \[`ImageFeatureExtractionPipeline`\].
# - `"image-segmentation"`: will return a \[`ImageSegmentationPipeline`\].
# - `"image-text-to-text"`: will return a \[`ImageTextToTextPipeline`\].
# - `"image-to-image"`: will return a \[`ImageToImagePipeline`\].
# - `"image-to-text"`: will return a \[`ImageToTextPipeline`\].
# - `"mask-generation"`: will return a \[`MaskGenerationPipeline`\].
# - `"object-detection"`: will return a \[`ObjectDetectionPipeline`\].
# - `"question-answering"`: will return a \[`QuestionAnsweringPipeline`\].
# - `"summarization"`: will return a \[`SummarizationPipeline`\].
# - `"table-question-answering"`: will return a \[`TableQuestionAnsweringPipeline`\].
# - `"text2text-generation"`: will return a \[`Text2TextGenerationPipeline`\].
# - `"text-classification"` (alias `"sentiment-analysis"` available): will return a
# [TextClassificationPipeline].
#     - "text-generation": will return a [TextGenerationPipeline]:.
#     - "text-to-audio" (alias "text-to-speech" available): will return a [TextToAudioPipeline]:.
#     - "token-classification" (alias "ner" available): will return a [TokenClassificationPipeline].
#     - "translation": will return a [TranslationPipeline].
#     - "translation_xx_to_yy": will return a [TranslationPipeline].
#     - "video-classification": will return a [VideoClassificationPipeline].
#     - "visual-question-answering": will return a [VisualQuestionAnsweringPipeline].
#     - "zero-shot-classification": will return a [ZeroShotClassificationPipeline].
#     - "zero-shot-image-classification": will return a [ZeroShotImageClassificationPipeline].
#     - "zero-shot-audio-classification": will return a [ZeroShotAudioClassificationPipeline].
#     - "zero-shot-object-detection": will return a [ZeroShotObjectDetectionPipeline].
#
#     model (str or [PreTrainedModel] or [TFPreTrainedModel], *optional*):
#         The model that will be used by the pipeline to make predictions. This can be a model identifier or an
# actual instance of a pretrained model inheriting from [PreTrainedModel] (for PyTorch) or
# [TFPreTrainedModel] (for TensorFlow).
#
#         If not provided, the default for the task will be loaded.
#     config (str or [PretrainedConfig], *optional*):
#         The configuration that will be used by the pipeline to instantiate the model. This can be a model
# identifier or an actual pretrained model configuration inheriting from [PretrainedConfig].
#
#         If not provided, the default configuration file for the requested model will be used. That means that if
# model is given, its default configuration will be used. However, if model is not supplied, this
# task's default model's config is used instead.
#     tokenizer (str or [PreTrainedTokenizer], *optional*):
#         The tokenizer that will be used by the pipeline to encode data for the model. This can be a model
# identifier or an actual pretrained tokenizer inheriting from [PreTrainedTokenizer].
#
#         If not provided, the default tokenizer for the given model will be loaded (if it is a string). If model
# is not specified or not a string, then the default tokenizer for config is loaded (if it is a string).
# However, if config is also not given or not a string, then the default tokenizer for the given task
# will be loaded.
#     feature_extractor (str or [PreTrainedFeatureExtractor], *optional*):
#         The feature extractor that will be used by the pipeline to encode data for the model. This can be a model
# identifier or an actual pretrained feature extractor inheriting from [PreTrainedFeatureExtractor].
#
#         Feature extractors are used for non-NLP models, such as Speech or Vision models as well as multi-modal
# models. Multi-modal models will also require a tokenizer to be passed.
#
#         If not provided, the default feature extractor for the given model will be loaded (if it is a string). If
# model is not specified or not a string, then the default feature extractor for config is loaded (if it
# is a string). However, if config is also not given or not a string, then the default feature extractor
# for the given task will be loaded.
#     image_processor (str or [BaseImageProcessor], *optional*):
#         The image processor that will be used by the pipeline to preprocess images for the model. This can be a
# model identifier or an actual image processor inheriting from [BaseImageProcessor].
#
#         Image processors are used for Vision models and multi-modal models that require image inputs. Multi-modal
# models will also require a tokenizer to be passed.
#
#         If not provided, the default image processor for the given model will be loaded (if it is a string). If
# model is not specified or not a string, then the default image processor for config is loaded (if it is
# a string).
#     processor (str or [ProcessorMixin], *optional*):
#         The processor that will be used by the pipeline to preprocess data for the model. This can be a model
# identifier or an actual processor inheriting from [ProcessorMixin].
#
#         Processors are used for multi-modal models that require multi-modal inputs, for example, a model that
# requires both text and image inputs.
#
#         If not provided, the default processor for the given model will be loaded (if it is a string). If model
# is not specified or not a string, then the default processor for config is loaded (if it is a string).
#     framework (str, *optional*):
#         The framework to use, either "pt" for PyTorch or "tf" for TensorFlow. The specified framework must be
# installed.
#
#         If no framework is specified, will default to the one currently installed. If no framework is specified and
# both frameworks are installed, will default to the framework of the model, or to PyTorch if no model is
# provided.
#     revision (str, *optional*, defaults to "main"):
#         When passing a task name or a string model identifier: The specific model version to use. It can be a
# branch name, a tag name, or a commit id, since we use a git-based system for storing models and other
# artifacts on huggingface.co, so revision can be any identifier allowed by git.
#     use_fast (bool, *optional*, defaults to True):
#         Whether or not to use a Fast tokenizer if possible (a [PreTrainedTokenizerFast]).
#     use_auth_token (str or *bool*, *optional*):
#         The token to use as HTTP bearer authorization for remote files. If True, will use the token generated
# when running huggingface-cli login (stored in ~/.huggingface).
#     device (int or str or torch.device):
#         Defines the device (*e.g.*, "cpu", "cuda:1", "mps", or a GPU ordinal rank like 1) on which this
# pipeline will be allocated.
#     device_map (str or Dict[str, Union[int, str, torch.device], *optional*):
#         Sent directly as model_kwargs (just a simpler shortcut). When accelerate library is present, set
# device_map="auto" to compute the most optimized device_map automatically (see
#         here
# for more information).
#
#         <Tip warning={true}>
#
#         Do not use device_map AND device at the same time as they will conflict
#
#         </Tip>
#
#     torch_dtype (str or torch.dtype, *optional*):
#         Sent directly as model_kwargs (just a simpler shortcut) to use the available precision for this model
# (torch.float16, torch.bfloat16, ... or "auto").
#     trust_remote_code (bool, *optional*, defaults to False):
#         Whether or not to allow for custom code defined on the Hub in their own modeling, configuration,
# tokenization or even pipeline files. This option should only be set to True for repositories you trust
# and in which you have read the code, as it will execute code present on the Hub on your local machine.
#     model_kwargs (Dict[str, Any], *optional*):
#         Additional dictionary of keyword arguments passed along to the model's from_pretrained(..., **model_kwargs) function.
#     kwargs (Dict[str, Any], *optional*):
#         Additional keyword arguments passed along to the specific pipeline init (see the documentation for the
# corresponding pipeline class for possible values).
#
# Returns:
#     [Pipeline]: A suitable pipeline for the task.
#
# Examples:
#
# >>> from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer
#
# >>> # Sentiment analysis pipeline
# >>> analyzer = pipeline("sentiment-analysis")
#
# >>> # Question answering pipeline, specifying the checkpoint identifier
# >>> oracle = pipeline(
# ...     "question-answering", model="distilbert/distilbert-base-cased-distilled-squad", tokenizer="google-bert/bert-base-cased"
# ... )
#
# >>> # Named entity recognition pipeline, passing in a specific model and tokenizer
# >>> model = AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")
# >>> tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-cased")
# >>> recognizer = pipeline("ner", model=model, tokenizer=tokenizer)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch
import gc
import os

# تنظيف الذاكرة
gc.collect()
torch.cuda.empty_cache()

# تعيين متغيرات البيئة
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['TRANSFORMERS_OFFLINE'] = '1'
os.environ['BITSANDBYTES_NOWELCOME'] = '1'
os.environ["FLASH_ATTENTION"] = "0"
# تحميل النموذج
model_id = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"
offload_dir = "./offload"  # تحديد مجلد مناسب لتخزين البيانات المؤقتة

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    torch_dtype=torch.float16,  # ضبط نوع البيانات إلى fp16 لتحسين الأداء
    offload_folder=offload_dir,
    trust_remote_code=True
)

# تحميل التوكنرايزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# إعداد `pipeline`
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto",
    max_memory={0: "13GiB"},  # الحد الأقصى للذاكرة المستخدمة
)

# تجربة تشغيل النموذج
response = pipe("Who are you?", max_new_tokens=5, do_sample=True)

print(response[0]['generated_text'])

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto",
    max_memory={0: "13GiB"},  # الحد الأقصى للذاكرة المستخدمة
)

# %% [markdown]
# ا

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# تعطيل Flash Attention لتقليل استهلاك الذاكرة
os.environ["FLASH_ATTENTION"] = "0"

# مسار تفريغ أجزاء من النموذج إلى القرص
offload_dir = "./offload"

# معرف النموذج
model_id = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

# تحميل التوكنيزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# تحميل النموذج مع تفريغ أجزاء إلى القرص
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",  # تعيين الجهاز تلقائيًا
    torch_dtype=torch.float16,  # تقليل استهلاك الذاكرة
    trust_remote_code=True,
    offload_folder=offload_dir,  # استخدام offloading للذاكرة
    offload_state_dict=True  # تمكين التفريغ للحالة الداخلية
)

# إعداد pipeline مع تحديد الحد الأقصى للذاكرة المتاحة
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto",
    max_memory={0: "13GiB"}  # ضبط الحد الأقصى للذاكرة المتاحة
)

# تجربة التوليد
prompt = "مرحبا، كيف يمكنني مساعدتك اليوم؟"
output = pipe(prompt, max_new_tokens=1)

# طباعة النتيجة
print(output[0]['generated_text'])
# Out:
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:418: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:461: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float16)
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# ...

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# تعطيل Flash Attention لتوفير الذاكرة
os.environ["FLASH_ATTENTION"] = "0"
import os
os.environ["TORCH_COMPILE"] = "0"

# مسار تفريغ أجزاء النموذج إلى الهارد
offload_dir = "./offload"

# معرف النموذج
model_id = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

# تحميل التوكنيزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# تحديد إدارة الذاكرة على GPU و RAM والهارد
max_memory = {
    0: "13GiB",  # تخصيص 13 جيجابايت للـ GPU
    "cpu": "11GiB",  # استخدام 32 جيجابايت من RAM
    "disk": "20GiB"  # تفريغ إضافي إلى الهارد عند الحاجة
}

# تحميل النموذج مع إدارة الذاكرة
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True,
    offload_folder=offload_dir,
    offload_state_dict=True,
    max_memory=max_memory,
    use_safetensors=True  # حل مشاكل التفريغ والتحميل
)

# إعداد pipeline
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto"
)

# تجربة التوليد
prompt = "مرحبا، كيف يمكنني مساعدتك اليوم؟"
output = pipe(prompt, max_new_tokens=1)

# طباعة النتيجة
print(output[0]['generated_text'])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-01b8e158eaac> in <cell line: 0>()
#      25
#      26 # تحميل النموذج مع إدارة الذاكرة
# ---> 27 model = AutoModelForCausalLM.from_pretrained(
#      28     model_id,
#      29     torch_dtype=torch.float16,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562         elif type(config) in cls._model_mapping.keys():
#     563             model_class = _get_model_class(config, cls._model_mapping)
# --> 564             return model_class.from_pretrained(
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566             )
#
# ...

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True,
    offload_folder=offload_dir,
    offload_state_dict=True,
    max_memory=max_memory,
    use_safetensors=True  # حل مشاكل التفريغ والتحميل
)

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# تعطيل Flash Attention لتوفير الذاكرة
os.environ["FLASH_ATTENTION"] = "0"
import os
os.environ["TORCH_COMPILE"] = "0"

# مسار تفريغ أجزاء النموذج إلى الهارد
offload_dir = "./offload"

# معرف النموذج
model_id = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

# تحميل التوكنيزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# تحديد إدارة الذاكرة على GPU و RAM
# Removed "disk" from max_memory
max_memory = {
    0: "13GiB",  # تخصيص 13 جيجابايت للـ GPU
    "cpu": "11GiB",  # استخدام 32 جيجابايت من RAM
}

# تحميل النموذج مع إدارة الذاكرة
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True,
    offload_folder=offload_dir,  # using offloading to manage memory
    offload_state_dict=True, # enabling offloading for the model's state dictionary
    max_memory=max_memory,
    use_safetensors=True  # to solve potential issues with offloading and loading
)

# إعداد pipeline
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto"
)

# تجربة التوليد
prompt = "مرحبا، كيف يمكنني مساعدتك اليوم؟"
output = pipe(prompt, max_new_tokens=1)

# طباعة النتيجة
print(output[0]['generated_text'])

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# معرف النموذج
model_id = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

# تعيين الذاكرة القصوى المسموح بها
max_memory = {0: "13GiB", "cpu": "11GiB"}  # GPU: 13GB, CPU RAM: 32GB

# مجلد التخزين المؤقت عند التفريغ إلى القرص
offload_dir = "./offload"

# التأكد من توفر CUDA
assert torch.cuda.is_available(), "CUDA غير متاحة، تأكد من تشغيل كودك على بيئة تدعم CUDA."

# تحميل النموذج
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,  # استخدام دقة 16 بت
    device_map="auto",  # تعيين الجهاز تلقائيًا
    trust_remote_code=True,
    max_memory=max_memory,
    offload_folder=offload_dir  # استخدام القرص عند الحاجة
)

# تحميل التوكنز
tokenizer = AutoTokenizer.from_pretrained(model_id)

# اختبار النموذج بجملة بسيطة
input_text = "مرحبا، كيف يمكنني مساعدتك اليوم؟"
inputs = tokenizer(input_text, return_tensors="pt").to("cuda")

# توليد النص
with torch.no_grad():
    output = model.generate(**inputs, max_length=200)

# طباعة النتيجة
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# تعطيل Flash Attention لتوفير الذاكرة
os.environ["FLASH_ATTENTION"] = "0"
import os
os.environ["TORCH_COMPILE"] = "0"

# مسار تفريغ أجزاء النموذج إلى الهارد
offload_dir = "./offload"

# معرف النموذج
model_id = "ChenMnZ/Llama-3-70b-instruct-EfficientQAT-w2g64-GPTQ"

# تحميل التوكنيزر
tokenizer = AutoTokenizer.from_pretrained(model_id)

# تحديد إدارة الذاكرة على GPU و RAM
# Removed "disk" from max_memory
max_memory = {
    0: "13GiB",  # تخصيص 13 جيجابايت للـ GPU
    "cpu": "11GiB",  # استخدام 32 جيجابايت من RAM
}

# تحميل النموذج مع إدارة الذاكرة
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True,
    offload_folder=offload_dir,  # using offloading to manage memory
    offload_state_dict=True, # enabling offloading for the model's state dictionary
    max_memory=max_memory,
    use_safetensors=True  # to solve potential issues with offloading and loading
)

# إعداد pipeline
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto"
)

# تجربة التوليد
prompt = "مرحبا، كيف يمكنني مساعدتك اليوم؟"
output = pipe(prompt, max_new_tokens=1)

# طباعة النتيجة
print(output[0]['generated_text'])
